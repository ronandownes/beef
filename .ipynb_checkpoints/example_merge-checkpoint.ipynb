# %%
import pandas as pd

# %%
land = pd.read_csv('land.csv')
land.head()
# Out:
#   Domain Code    Domain  Area Code (M49)         Area  Element Code Element  \
# 0          RL  Land Use                4  Afghanistan          5110    Area
# 1          RL  Land Use                4  Afghanistan          5110    Area
# 2          RL  Land Use                4  Afghanistan          5110    Area
# 3          RL  Land Use                4  Afghanistan          5110    Area
# 4          RL  Land Use                4  Afghanistan          5110    Area
#
#    Item Code                                   Item  Year Code  Year     Unit  \
# 0       6633  Land under temp. meadows and pastures       2001  2001  1000 ha
# 1       6633  Land under temp. meadows and pastures       2002  2002  1000 ha
# 2       6633  Land under temp. meadows and pastures       2003  2003  1000 ha
# 3       6633  Land under temp. meadows and pastures       2004  2004  1000 ha
# 4       6633  Land under temp. meadows and pastures       2005  2005  1000 ha
#
#    Value Flag Flag Description
# ...

# %%
cattle = pd.read_csv('cattle.csv')
cattle.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)         Area  \
# 0         QCL  Crops and livestock products                4  Afghanistan
# 1         QCL  Crops and livestock products                4  Afghanistan
# 2         QCL  Crops and livestock products                4  Afghanistan
# 3         QCL  Crops and livestock products                4  Afghanistan
# 4         QCL  Crops and livestock products                4  Afghanistan
#
#    Element Code Element  Item Code (CPC)    Item  Year Code  Year  Unit  \
# 0          5111  Stocks             2111  Cattle       1961  1961  Head
# 1          5111  Stocks             2111  Cattle       1962  1962  Head
# 2          5111  Stocks             2111  Cattle       1963  1963  Head
# 3          5111  Stocks             2111  Cattle       1964  1964  Head
# 4          5111  Stocks             2111  Cattle       1965  1965  Head
#
#      Value Flag Flag Description
# 0  2900000    A  Official figure
# ...

# %% [markdown]
# lets say we want to merge the value column from the land column onto the cattle dataframe

# %%
#first create a unique key in the cattle dataframe
cattle['key'] = cattle['Year'].astype(str) + cattle['Area'].astype(str)

#then create a unique key in the land dataframe
land['key'] = land['Year'].astype(str) + land['Area'].astype(str)

# %%
#now just filter the columns that we want from the land df. this will be the value and key column here
land = land[['key', 'Value']]
#rename value to land use Kha
land = land.rename(columns={'Value': 'Land Use Kha'})
land.head()
# Out:
#                key  Land Use Kha
# 0  2001Afghanistan           0.0
# 1  2002Afghanistan           0.0
# 2  2003Afghanistan           0.0
# 3  2004Afghanistan           0.0
# 4  2005Afghanistan           0.0

# %%
#now we can merge the two dataframes
cattle_merged = pd.merge(cattle_df, land_df, on='key')
cattle_merged

# %%
cattle_merged
# Out:
#       Domain Code                        Domain  Area Code (M49)         Area  \
# 0             QCL  Crops and livestock products                4  Afghanistan
# 1             QCL  Crops and livestock products                4  Afghanistan
# 2             QCL  Crops and livestock products                4  Afghanistan
# 3             QCL  Crops and livestock products                4  Afghanistan
# 4             QCL  Crops and livestock products                4  Afghanistan
# ...           ...                           ...              ...          ...
# 14402         QCL  Crops and livestock products              716     Zimbabwe
# 14403         QCL  Crops and livestock products              716     Zimbabwe
# 14404         QCL  Crops and livestock products              716     Zimbabwe
# 14405         QCL  Crops and livestock products              716     Zimbabwe
# 14406         QCL  Crops and livestock products              716     Zimbabwe
#
# ...
