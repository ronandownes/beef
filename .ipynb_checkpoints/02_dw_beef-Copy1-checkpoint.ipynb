# %% [markdown]
# <h1>Table of Contents (Clickable in sidebar)<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#The-revised-research-question" data-toc-modified-id="The-revised-research-question-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>The revised research question</a></span></li><li><span><a href="#Libraries,---modules-and-orientation" data-toc-modified-id="Libraries,---modules-and-orientation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Libraries,   modules and orientation</a></span></li><li><span><a href="#Combine-CCKP--Timeseries-Files-and-Add-a-CountryYear-Key" data-toc-modified-id="Combine-CCKP--Timeseries-Files-and-Add-a-CountryYear-Key-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Combine CCKP  Timeseries Files and Add a CountryYear Key</a></span></li><li><span><a href="#The-Climate-Change-Knowledge-Portal.-(n.d.).-Retrieved-February-20,-2023,-from-https://climateknowledgeportal.worldbank.org/" data-toc-modified-id="The-Climate-Change-Knowledge-Portal.-(n.d.).-Retrieved-February-20,-2023,-from-https://climateknowledgeportal.worldbank.org/-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>The Climate Change Knowledge Portal. (n.d.). Retrieved February 20, 2023, from <a href="https://climateknowledgeportal.worldbank.org/" rel="nofollow" target="_blank">https://climateknowledgeportal.worldbank.org/</a></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#CCKP-Data--and-an-initial-bit-of-EDA" data-toc-modified-id="CCKP-Data--and-an-initial-bit-of-EDA-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>CCKP Data  and an initial bit of EDA</a></span></li></ul></li></ul></li><li><span><a href="#The-FAOSTAT-and-CCKP-data-become-one!" data-toc-modified-id="The-FAOSTAT-and-CCKP-data-become-one!-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>The FAOSTAT and CCKP data become one!</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Pascal" data-toc-modified-id="Pascal-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Pascal</a></span></li><li><span><a href="#Rename" data-toc-modified-id="Rename-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>Rename</a></span></li><li><span><a href="#Replace" data-toc-modified-id="Replace-5.0.3"><span class="toc-item-num">5.0.3&nbsp;&nbsp;</span>Replace</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Data Wrangling   for Irish Beef
#
# ## The revised research question
# How has Ireland's beef sector performed compared to the EU 27 countries since 2000, and can we forecast future prices using this historical data? Additionally, what can we learn from sentiment analysis of the beef industry during this time period? By focusing on data from 2000 onwards, we can better capture the current state of the beef industry and make more relevant predictions about future trends. At the end of 1999, the Benelux union ceased to report beef stock data as a single entity, as each member country began reporting its data individually. This change reflected the increasing economic development and growth of the individual countries within the union. This not only created the data reason for us to only researh the 21st era but it also provides a fiscal reason for the refining of the researh question.
# ## Libraries,   modules and orientation

# %%
### Data Manipulation and Analysis
import csv
import pandas as pd
import numpy as np
import fancyimpute
import missingno as msno
from functools import partial, reduce

### Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib.image as mpimg

### Statistical Analysis
from scipy.stats import ks_2samp, shapiro

### Machine Learning
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import ElasticNet, Lasso, LinearRegression, Ridge
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR

### Text Processing

import html
import re
import inflection

### Country Information
from countryinfo import CountryInfo
import pycountry
from countrygroups import EUROPEAN_UNION

### File System and OS
import glob
import os

### Date and Time
import datetime
import time

### Data Presentation
from tabulate import tabulate
from IPython.display import HTML, Image, display

### Data Types
from typing import Dict, List, Tuple

os.getcwd()
# Out:
# 'C:\\Users\\ronan\\beef'

# %% [markdown]
# ##  Combine CCKP  Timeseries Files and Add a CountryYear Key
#
# The combine_timeseries_files function reads multiple CSV files from the rain or temperature subfolders.Referencing the first five rows of Rain_IRL_df  below  the first unnamed column gives the year and based on position the name of the country is extracted. The function then forms a Key by concatrenating the Country and Year values together. This 'Key' column  will be  used to merge with our Cattle Stocks data   to single dataframe. It filters to only include the first two columns, which are Year and corresponding weather measurements and as such, it drops all redundant regional readings. The resulting dataframe contains the weather data of 27 European countries.

# %%
Rain_IRL_df = pd.read_csv('rain/pr_timeseries_annual_cru_1901-2021_IRL.csv')# loads the individual Irish rain data
Rain_IRL_df.head()
# Out:
#                                                                                                                                                                                                                                    Variable:  \
# NaN    Ireland Carlow  Cavan   Clare   Cork    Donegal Dublin  Galway  Kerry   Kildare Kilkenny Laois   Leitrim Limerick Longford Louth   Mayo    Meath   Monaghan Munster Offaly  Roscommon Sligo   Tipperary Waterford Westmeath   Wexford
# 1901.0 1068.52 983.20  1018.93 1055.24 1153.06 1288.02 942.31  1044.95 1323.52 861.02  945.54   882.59  1184.19 1059.33  986.53   875.52  1156.31 861.07  933.47   933.47  851.14  1008.41   1206.83 1030.92   1129.96   901.61       988.85
# 1902.0 1016.31 965.42  939.44  1004.48 1119.44 1167.77 934.83  984.17  1277.05 857.92  926.28   863.97  1076.99 1022.06  907.86   834.92  1053.70 824.53  864.39   864.39  831.83  943.86    1087.75 1002.13   1101.99   852.81       967.98
# 1903.0 1368.16 1282.10 1235.62 1376.31 1525.32 1564.40 1197.84 1350.96 1747.10 1101.33 1236.78  1156.36 1443.61 1392.88  1209.04  1055.55 1445.43 1055.06 1131.68  1131.68 1116.15 1280.60   1479.39 1355.40   1484.59   1134.94     1275.17
# 1904.0 1081.95 970.03  985.97  1114.46 1235.12 1282.28 902.41  1069.77 1421.42 844.14  938.61   872.85  1151.71 1107.92  946.22   824.66  1164.06 826.20  906.37   906.37  840.18  1003.16   1173.82 1041.08   1144.26   873.39       974.31
#
#                                                                                                                                                                                                                                          pr
# NaN    Ireland Carlow  Cavan   Clare   Cork    Donegal Dublin  Galway  Kerry   Kildare Kilkenny Laois   Leitrim Limerick Longford Louth   Mayo    Meath   Monaghan Munster Offaly  Roscommon Sligo   Tipperary Waterford Westmeath  Wicklow
# 1901.0 1068.52 983.20  1018.93 1055.24 1153.06 1288.02 942.31  1044.95 1323.52 861.02  945.54   882.59  1184.19 1059.33  986.53   875.52  1156.31 861.07  933.47   933.47  851.14  1008.41   1206.83 1030.92   1129.96   901.61      978.16
# 1902.0 1016.31 965.42  939.44  1004.48 1119.44 1167.77 934.83  984.17  1277.05 857.92  926.28   863.97  1076.99 1022.06  907.86   834.92  1053.70 824.53  864.39   864.39  831.83  943.86    1087.75 1002.13   1101.99   852.81      966.45
# 1903.0 1368.16 1282.10 1235.62 1376.31 1525.32 1564.40 1197.84 1350.96 1747.10 1101.33 1236.78  1156.36 1443.61 1392.88  1209.04  1055.55 1445.43 1055.06 1131.68  1131.68 1116.15 1280.60   1479.39 1355.40   1484.59   1134.94    1256.88
# 1904.0 1081.95 970.03  985.97  1114.46 1235.12 1282.28 902.41  1069.77 1421.42 844.14  938.61   872.85  1151.71 1107.92  946.22   824.66  1164.06 826.20  906.37   906.37  840.18  1003.16   1173.82 1041.08   1144.26   873.39      950.28

# %% [markdown]
# ## The Climate Change Knowledge Portal. (n.d.). Retrieved February 20, 2023, from https://climateknowledgeportal.worldbank.org/
#
# The Climate Change Knowledge Portal. (n.d.). Retrieved February 20, 2023, from https://climateknowledgeportal.worldbank.org/
# To maintain consistency with the FAO data, annual and not monthly time series  aggregates were taken from the Climatic Research Unit (CRU) dataset for **precipitation** and   **mean-temperature**. These datasets are provided by the CRU TS 4.04 dataset, a gridded climate dataset produced by the Climatic Research Unit (CRU) at the University of East Anglia in the United Kingdom. In the statistics section, range, variance, and standard deviation of monthly data may be revisited for insights.
#
# The file names and folder names of the CCKP data used in this project are tabulated below.
#
# <span style="font-size: 24px;">Table : Table shows Time Series data filenames and folders  for 27 EU countries from  CCKP site </span>
#
#
#
# | Country        | Code | TasAnnual (Folder with Tempature data)                              | PrAnnual   (Folder with Precipitation Data)                        |
# |:--------------:|:----:|:--------------------------------------:|:---------------------------------:|
# | Albania        | ALB  | tas_timeseries_annual_cru_1901-2021_ALB.csv | pr_timeseries_annual_cru_1901-2021_ALB.csv |
# | Andorra        | AND  | tas_timeseries_annual_cru_1901-2021_AND.csv | pr_timeseries_annual_cru_1901-2021_AND.csv |
# | Austria        | AUT  | tas_timeseries_annual_cru_1901-2021_AUT.csv | pr_timeseries_annual_cru_1901-2021_AUT.csv |
# | Belarus        | BLR  | tas_timeseries_annual_cru_1901-2021_BLR.csv | pr_timeseries_annual_cru_1901-2021_BLR.csv |
# | Belgium        | BEL  | tas_timeseries_annual_cru_1901-2021_BEL.csv | pr_timeseries_annual_cru_1901-2021_BEL.csv |
# | Bosnia and Herzegovina | BIH  | tas_timeseries_annual_cru_1901-2021_BIH.csv | pr_timeseries_annual_cru_1901-2021_BIH.csv |
# | Bulgaria       | BGR  | tas_timeseries_annual_cru_1901-2021_BGR.csv | pr_timeseries_annual_cru_1901-2021_BGR.csv |
# | Croatia        | HRV  | tas_timeseries_annual_cru_1901-2021_HRV.csv | pr_timeseries_annual_cru_1901-2021_HRV.csv |
# | Cyprus         | CYP  | tas_timeseries_annual_cru_1901-2021_CYP.csv | pr_timeseries_annual_cru_1901-2021_CYP.csv |
# | Czech Republic | CZE  | tas_timeseries_annual_cru_1901-2021_CZE.csv | pr_timeseries_annual_cru_1901-2021_CZE.csv |
# | Denmark        | DNK  | tas_timeseries_annual_cru_1901-2021_DNK.csv | pr_timeseries_annual_cru_1901-2021_DNK.csv |
# | Estonia        | EST  | tas_timeseries_annual_cru_1901-2021_EST.csv | pr_timeseries_annual_cru_1901-2021_EST.csv |
# | Finland        | FIN  | tas_timeseries_annual_cru_1901-2021_FIN.csv | pr_timeseries_annual_cru_1901-2021_FIN.csv |
# | France         | FRA  | tas_timeseries_annual_cru_1901-2021_FRA.csv | pr_timeseries_annual_cru_1901-2021_FRA.csv |
# | Germany        | DEU  | tas_timeseries_annual_cru_1901-2021_DEU.csv | pr_timeseries_annual_cru_1901-2021_DEU.csv |
# | Gibraltar      | GIB  | tas_timeseries_annual_cru_1901-2021_GIB.csv | pr_timeseries_annual_cru_1901-2021_GIB.csv |
# | Greece | GRC | tas_timeseries_annual_cru_1901-2021_GRC.csv | pr_timeseries_annual_cru_1901-2021_GRC.csv |
# | Croatia | HRV | tas_timeseries_annual_cru_1901-2021_HRV.csv | pr_timeseries_annual_cru_1901-2021_HRV.csv |
# | Hungary | HUN | tas_timeseries_annual_cru_1901-2021_HUN.csv | pr_timeseries_annual_cru_1901-2021_HUN.csv |
# | Ireland | IRL | tas_timeseries_annual_cru_1901-2021_IRL.csv | pr_timeseries_annual_cru_1901-2021_IRL.csv |
# | Italy | ITA | tas_timeseries_annual_cru_1901-2021_ITA.csv | pr_timeseries_annual_cru_1901-2021_ITA.csv |
# | Lithuania | LTU | tas_timeseries_annual_cru_1901-2021_LTU.csv | pr_timeseries_annual_cru_1901-2021_LTU.csv |
# | Luxembourg | LUX | tas_timeseries_annual_cru_1901-2021_LUX.csv | pr_timeseries_annual_cru_1901-2021_LUX.csv |
# | Latvia | LVA | tas_timeseries_annual_cru_1901-2021_LVA.csv | pr_timeseries_annual_cru_1901-2021_LVA.csv |
# | Malta | MLT | tas_timeseries_annual_cru_1901-2021_MLT.csv | pr_timeseries_annual_cru_1901-2021_MLT.csv |
# | Netherlands | NLD | tas_timeseries_annual_cru_1901-2021_NLD.csv | pr_timeseries_annual_cru_1901-2021_NLD.csv |
# | Poland | POL | tas_timeseries_annual_cru_1901-2021_POL.csv | pr_timeseries_annual_cru_1901-2021_POL.csv |
# | Portugal | PRT | tas_timeseries_annual_cru_1901-2021_PRT.csv | pr_timeseries_annual_cru_1901-2021_PRT.csv |
# | Romania | ROU | tas_timeseries_annual_cru_1901-2021_ROU.csv | pr_timeseries_annual_cru_1901-2021_ROU.csv |
# | Slovakia | SVK | tas_timeseries_annual_cru_1901-2021_SVK.csv | pr_timeseries_annual_cru_1901-2021_SVK.csv |
# | Slovenia | SVN | tas_timeseries_annual_cru_1901-2021_SVN.csv | pr_timeseries_annual_cru_1901-2021_SVN.csv |
# | Sweden | SWE | tas_timeseries_annual_cru_1901-2021_SWE.csv | pr_timeseries_annual_cru_1901-2021_SWE.csv |
#
#
# All datasets from the CCKP are licensed under the Creative Commons Attribution-NonCommercial-ShareAlike 3.0 IGO (CC BY-NC-SA 3.0 IGO).
# Source: CCKP (2023). Time Series datasets. Retrieved from [https://climateknowledgeportal.worldbank.org/download-data].

# %% [markdown]
# ####   CCKP Data  and an initial bit of EDA
#
# <div style="display: flex; justify-content: center;">
#   <img src="../images/we28.png" alt="image19" style="width: 30%;">
#   <img src="../images/we29.png" alt="image20" style="width: 30%;">
#     <img src="../images/we30.png" alt="image20" style="width: 30%;">
# </div>
#
# <span style="font-size: 18px;">Figure 3:Time Series Data downloaded for 27 EU countries from  CCKP site </span>

# %%
def combine_timeseries_files(path: str, subfolder: str, col_name: str) -> pd.DataFrame:
    """Reads in all CSV files in the given subfolder of the directory, renames the first unnamed column based on its position,
    and combines the resulting dataframes together into a single dataframe.
    Args:
        path (str): The relative path of the directory containing the data.
        subfolder (str): The name of the subfolder within the directory to read the CSV files from.
        col_name (str): The name to assign to the specified column in the resulting dataframe.
    Returns:
        pandas.DataFrame: The resulting dataframe after combining data from all CSV files in the specified subfolder.
    """
    try:
        folder_path = os.path.join(path, subfolder)
        csv_filenames = glob.glob(folder_path + "/*.csv")
        # Read in all CSV files, rename the first unnamed column based on position, and filter to only include the 'key' and specified column
        processed_dfs = []
        for filename in csv_filenames:
            file_path = os.path.join(path, subfolder, os.path.basename(filename))
            df = pd.read_csv(file_path, on_bad_lines='skip', skiprows=1)
            if df.columns[0].startswith("Unnamed"):
                df.rename(columns={df.columns[0]: "Year"}, inplace=True)
            df['Key'] = df.columns[1] + df['Year'].astype(str)
            df.rename(columns={df.columns[1]: col_name}, inplace=True)
            df = df.filter(['Key', col_name])
            processed_dfs.append(df)
        # Concatenate all dataframes into a single dataframe
        df = pd.concat(processed_dfs, ignore_index=True)
        return df
    except Exception as e:
        print(f"Error combining CSV files in folder {folder_path}: {e}")

# %% [markdown]
# ## The FAOSTAT and CCKP data become one!

# %%
rain_df = combine_timeseries_files('', 'rain', 'R_mm/y')
# save the rain DataFrame to a CSV file
rain_df.to_csv('clean/rain.csv', index=False)
rain_df.head()
# Out:
#            Key   R_mm/y
# 0  Austria1901  1052.84
# 1  Austria1902  1061.55
# 2  Austria1903  1201.34
# 3  Austria1904  1146.14
# 4  Austria1905  1127.85

# %%
temperature_df = combine_timeseries_files('', 'temperature', 'T\u00b0C')
# save the rain DataFrame to a CSV file
temperature_df.to_csv('clean/temperature.csv', index=False)
temperature_df
# Out:
#               Key   T°C
# 0     Austria1901  5.41
# 1     Austria1902  5.34
# 2     Austria1903  5.88
# 3     Austria1904  6.22
# 4     Austria1905  5.79
# ...           ...   ...
# 3262   Sweden2017  3.16
# 3263   Sweden2018  3.62
# 3264   Sweden2019  3.34
# 3265   Sweden2020  4.47
# 3266   Sweden2021  3.02
#
# [3267 rows x 2 columns]

# %%
main_df = pd.read_csv('clean/stock.csv')# loads the cleaned cattle stock  CSV file to pandas DataFrame n df
main_df
# Out:
#      Country  Year    Stock
# 0    Austria  2000  2152811
# 1    Austria  2001  2155447
# 2    Austria  2002  2118454
# 3    Austria  2003  2066942
# 4    Austria  2004  2052033
# ..       ...   ...      ...
# 589   Sweden  2017  1448590
# 590   Sweden  2018  1435450
# 591   Sweden  2019  1404670
# 592   Sweden  2020  1390960
# 593   Sweden  2021  1389890
#
# [594 rows x 3 columns]

# %%
# assuming the dataframe is called 'df'
main_df['Key'] = main_df['Country'].str.cat(main_df['Year'].astype(str), sep='_')
main_df
# Out:
#      Country  Year    Stock           Key
# 0    Austria  2000  2152811  Austria_2000
# 1    Austria  2001  2155447  Austria_2001
# 2    Austria  2002  2118454  Austria_2002
# 3    Austria  2003  2066942  Austria_2003
# 4    Austria  2004  2052033  Austria_2004
# ..       ...   ...      ...           ...
# 589   Sweden  2017  1448590   Sweden_2017
# 590   Sweden  2018  1435450   Sweden_2018
# 591   Sweden  2019  1404670   Sweden_2019
# 592   Sweden  2020  1390960   Sweden_2020
# 593   Sweden  2021  1389890   Sweden_2021
#
# [594 rows x 4 columns]

# %%
"""
Adds a unique key column to our dataframe 
based on the "Country" and "Year" columns by casting year to string type.
"""
main_df['Key'] = main_df['Country'] + main_df['Year'].astype(str)# adds a unique key column 
main_df
# Out:
#      Country  Year    Stock          Key
# 0    Austria  2000  2152811  Austria2000
# 1    Austria  2001  2155447  Austria2001
# 2    Austria  2002  2118454  Austria2002
# 3    Austria  2003  2066942  Austria2003
# 4    Austria  2004  2052033  Austria2004
# ..       ...   ...      ...          ...
# 589   Sweden  2017  1448590   Sweden2017
# 590   Sweden  2018  1435450   Sweden2018
# 591   Sweden  2019  1404670   Sweden2019
# 592   Sweden  2020  1390960   Sweden2020
# 593   Sweden  2021  1389890   Sweden2021
#
# [594 rows x 4 columns]

# %%
main_df = pd.merge(main_df, rain_df, on='Key')
main_df.head()
# Out:
#    Country  Year    Stock          Key   R_mm/y
# 0  Austria  2000  2152811  Austria2000  1171.79
# 1  Austria  2001  2155447  Austria2001  1058.36
# 2  Austria  2002  2118454  Austria2002  1212.56
# 3  Austria  2003  2066942  Austria2003   891.80
# 4  Austria  2004  2052033  Austria2004  1080.30

# %%
main_df = pd.merge(main_df, temperature_df, on='Key')
main_df
# Out:
#      Country  Year    Stock          Key   R_mm/y   T°C
# 0    Austria  2000  2152811  Austria2000  1171.79  7.97
# 1    Austria  2001  2155447  Austria2001  1058.36  7.03
# 2    Austria  2002  2118454  Austria2002  1212.56  7.73
# 3    Austria  2003  2066942  Austria2003   891.80  7.35
# 4    Austria  2004  2052033  Austria2004  1080.30  6.75
# ..       ...   ...      ...          ...      ...   ...
# 589   Sweden  2017  1448590   Sweden2017   678.22  3.16
# 590   Sweden  2018  1435450   Sweden2018   539.63  3.62
# 591   Sweden  2019  1404670   Sweden2019   682.36  3.34
# 592   Sweden  2020  1390960   Sweden2020   669.34  4.47
# 593   Sweden  2021  1389890   Sweden2021   608.87  3.02
#
# [594 rows x 6 columns]

# %%
#### Snake
def snake(text, default='default'):
    """
    Converts a given string to snake_case by replacing any whitespace characters with underscores,
    converting to all lowercase, and removing any non-alphanumeric characters from the beginning and end.

    Parameters:
        text (str): The string to convert to snake_case.
        default (str): The default value to return if the input text is empty.

    Returns:
        str: The resulting string in snake_case format, or the default value if the input text is empty.
    """
    if not text:
        return default
    # Convert to string and replace any non-alphanumeric characters at the beginning and end with an empty string
    text = re.sub(r'^\W+|\W+$', '', str(text))
    # Replace any period symbols with underscores
    text = text.replace('.', '')
    # Replace any other non-alphanumeric characters with empty strings
    text = re.sub(r'\W+', '_', text)
    # Convert to all lowercase
    text = text.lower()
    return text

# Example usage:
text = "This is a text with pe,  ,  ,  ,riods. (And other characters   .)"
result = snake(text)
print(result)  # Output: "this_is_a_text_with_periods_and_other_characters"


# snake('does snake Work')

# snake('                  ')
# snake('                  ')
# snake('                  ')
# Out:
# this_is_a_text_with_pe_riods_and_other_characters

# %%
# Read in the original DataFrame
df = pd.read_csv('raw/nutrient.csv')
print(df.nunique())
# Out:
# Domain Code             1
# Domain                  1
# Area Code (M49)        28
# Area                   28
# Element Code            4
# Element                 4
# Item Code               3
# Item                    3
# Year Code              60
# Year                   60
# Unit                    1
# Value               11031
# Flag                    5
# Flag Description        5
# dtype: int64

# %%
# rename the 'Area' column to 'Country'
df = df.rename(columns={'Area': 'Country'})

# %%
# create a 'Key' column by concatenating 'Country' and 'Year'
df['Key'] = df['Country'] + df['Year'].astype(str)

# %%
# keep the 'Value' column
df = df[['Element','Item','Key', 'Value']]

# print the final dataframe
df
# Out:
#                 Element                         Item          Key     Value
# 0            Production  Nutrient nitrogen N (total)  Austria1961  172380.0
# 1            Production  Nutrient nitrogen N (total)  Austria1962  173422.0
# 2            Production  Nutrient nitrogen N (total)  Austria1963  169812.0
# 3            Production  Nutrient nitrogen N (total)  Austria1964  184900.0
# 4            Production  Nutrient nitrogen N (total)  Austria1965  211070.0
# ...                 ...                          ...          ...       ...
# 20155  Agricultural Use  Nutrient potash K2O (total)   Sweden2016   35077.0
# 20156  Agricultural Use  Nutrient potash K2O (total)   Sweden2017   36791.0
# 20157  Agricultural Use  Nutrient potash K2O (total)   Sweden2018   38985.0
# 20158  Agricultural Use  Nutrient potash K2O (total)   Sweden2019   36070.0
# 20159  Agricultural Use  Nutrient potash K2O (total)   Sweden2020   43652.0
#
# [20160 rows x 4 columns]

# %%
df['Item'] = df['Item'].apply(snake)
df['Element'] = df['Element'].apply(snake)

# %%
item=df['Item'].unique()
item
# Out:
# array(['nutrient_nitrogen_n_total', 'nutrient_phosphate_p2o5_total',
#        'nutrient_potash_k2o_total'], dtype=object)

# %%
# df['Element'] = df['Element'].str.lower().str.replace(' ', '_')
elements = df['Element'].unique()
elements
# Out:
# array(['production', 'import_quantity', 'export_quantity',
#        'agricultural_use'], dtype=object)

# %%
df
# Out:
#                 Element                       Item          Key     Value
# 0            production  nutrient_nitrogen_n_total  Austria1961  172380.0
# 1            production  nutrient_nitrogen_n_total  Austria1962  173422.0
# 2            production  nutrient_nitrogen_n_total  Austria1963  169812.0
# 3            production  nutrient_nitrogen_n_total  Austria1964  184900.0
# 4            production  nutrient_nitrogen_n_total  Austria1965  211070.0
# ...                 ...                        ...          ...       ...
# 20155  agricultural_use  nutrient_potash_k2o_total   Sweden2016   35077.0
# 20156  agricultural_use  nutrient_potash_k2o_total   Sweden2017   36791.0
# 20157  agricultural_use  nutrient_potash_k2o_total   Sweden2018   38985.0
# 20158  agricultural_use  nutrient_potash_k2o_total   Sweden2019   36070.0
# 20159  agricultural_use  nutrient_potash_k2o_total   Sweden2020   43652.0
#
# [20160 rows x 4 columns]

# %%
agricultural_use_nutrient_nitrogen_n_total
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13012\1374547524.py in <module>
# ----> 1 agricultural_use_nutrient_nitrogen_n_total
#
# NameError: name 'agricultural_use_nutrient_nitrogen_n_total' is not defined

# %%
# Define a function to create a new DataFrame for a given group
def create_df(group):
    element_name = group['Element'].iloc[0]
    item_name = group['Item'].iloc[0]
    new_df = group.copy()
    new_df['Element'] = element_name
    new_df['Item'] = item_name
    new_df.columns = [inflection.underscore(col) for col in new_df.columns] # rename columns to snake_case
    df_name = f'{inflection.underscore(element_name)}_{inflection.underscore(item_name)}'
    return df_name, new_df

# Group the original dataframe by Element and Item, and loop through the resulting groups to create new DataFrames
dfs = {}
for (element, item), group in df.groupby(['Element', 'Item']):
    df_name, new_df = create_df(group)
    dfs[df_name] = new_df

# Print the resulting DataFrames
for name, df in dfs.items():
    print(name)
df
# Out:
# agricultural_use_nutrient_nitrogen_n_total
# agricultural_use_nutrient_phosphate_p2o5_total
# agricultural_use_nutrient_potash_k2o_total
# export_quantity_nutrient_nitrogen_n_total
# export_quantity_nutrient_phosphate_p2o5_total
# export_quantity_nutrient_potash_k2o_total
# import_quantity_nutrient_nitrogen_n_total
# import_quantity_nutrient_phosphate_p2o5_total
# import_quantity_nutrient_potash_k2o_total
# production_nutrient_nitrogen_n_total
# production_nutrient_phosphate_p2o5_total
# production_nutrient_potash_k2o_total
#           element                       item          key  value
# 480    production  nutrient_potash_k2o_total  Austria1961    NaN
# 481    production  nutrient_potash_k2o_total  Austria1962    NaN
# 482    production  nutrient_potash_k2o_total  Austria1963    NaN
# 483    production  nutrient_potash_k2o_total  Austria1964    NaN
# 484    production  nutrient_potash_k2o_total  Austria1965    NaN
# ...           ...                        ...          ...    ...
# 19975  production  nutrient_potash_k2o_total   Sweden2016    0.0
# 19976  production  nutrient_potash_k2o_total   Sweden2017    0.0
# 19977  production  nutrient_potash_k2o_total   Sweden2018    0.0
# 19978  production  nutrient_potash_k2o_total   Sweden2019    0.0
# 19979  production  nutrient_potash_k2o_total   Sweden2020    0.0
#
# [1680 rows x 4 columns]

# %%
create_df('df')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13012\3043656600.py in <module>
# ----> 1 create_df('df')
#
# ~\AppData\Local\Temp\ipykernel_13012\1759841653.py in create_df(group)
#       8 # Define a function to create a new DataFrame for a given group
#       9 def create_df(group):
# ---> 10     element_name = group['Element'].iloc[0]
#      11     item_name = group['Item'].iloc[0]
#      12     new_df = group.copy()
#
# TypeError: string indices must be integers

# %%
replace_dict = {'Nutrient nitrogen N (total)': 'N', 'Nutrient phosphate P2O5 (total)': 'P2O5', 'Nutrient potash K2O (total)': 'K2O'}

# %%
df['Item'] = df['Item'].replace(replace_dict)
item=df['Item'].unique()
item
# Out:
# array(['N', 'P2O5', 'K2O'], dtype=object)

# %%
df['Item'] = df['Item'].apply(snake)
item=df['Item'].unique()
item
# Out:
# array(['nutrient_nitrogen_n_total', 'nutrient_phosphate_p2o5_total',
#        'nutrient_potash_k2o_total'], dtype=object)

# %%
coun= df_11['Area'].unique()
coun
# Out:
# array(['Austria', 'Belgium', 'Belgium-Luxembourg', 'Bulgaria', 'Croatia',
#        'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland',
#        'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden'],
#       dtype=object)

# %%
df_11 = df[(df['Element'] == 'production') & (df['Item'] == 'N')]
df_12 = df[(df['Element'] == 'production') & (df['Item'] == 'P2O5')]
df_13 = df[(df['Element'] == 'production') & (df['Item'] == 'K20')]
df_14 = df[(df['Element'] == 'import_quantity') & (df['Item'] == 'N')]
df_15 = df[(df['Element'] == 'import_quantity') & (df['Item'] == 'P2O5')]
df_16 = df[(df['Element'] == 'import_quantity') & (df['Item'] == 'K20')]
df_17 = df[(df['Element'] == 'export_quantity') & (df['Item'] == 'N')]
df_18 = df[(df['Element'] == 'export_quantity') & (df['Item'] == 'P2O5')]
df_19 = df[(df['Element'] == 'export_quantity') & (df['Item'] == 'K20')]
df_20 = df[(df['Element'] == 'agricultural_use') & (df['Item'] == 'N')]
df_21 = df[(df['Element'] == 'agricultural_use') & (df['Item'] == 'P2O5')]
df_22 = df[(df['Element'] == 'agricultural_use') & (df['Item'] == 'K20')]

# %%
def key(df)
 df['Key'] = df['Country'] + df['Year'].astype(str)# adds a unique key column

# %%
p2o5_production_df=df_12
p2o5_production_df
# Out:
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 240           RFN  Fertilizers by Nutrient               40  Austria
# 241           RFN  Fertilizers by Nutrient               40  Austria
# 242           RFN  Fertilizers by Nutrient               40  Austria
# 243           RFN  Fertilizers by Nutrient               40  Austria
# 244           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19735         RFN  Fertilizers by Nutrient              752   Sweden
# 19736         RFN  Fertilizers by Nutrient              752   Sweden
# 19737         RFN  Fertilizers by Nutrient              752   Sweden
# 19738         RFN  Fertilizers by Nutrient              752   Sweden
# 19739         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code     Element  Item Code  Item  Year Code  Year    Unit  \
# 240            5510  production       3103  P2O5       1961  1961  tonnes
# 241            5510  production       3103  P2O5       1962  1962  tonnes
# 242            5510  production       3103  P2O5       1963  1963  tonnes
# 243            5510  production       3103  P2O5       1964  1964  tonnes
# 244            5510  production       3103  P2O5       1965  1965  tonnes
# ...             ...         ...        ...   ...        ...   ...     ...
# 19735          5510  production       3103  P2O5       2016  2016  tonnes
# 19736          5510  production       3103  P2O5       2017  2017  tonnes
# 19737          5510  production       3103  P2O5       2018  2018  tonnes
# 19738          5510  production       3103  P2O5       2019  2019  tonnes
# 19739          5510  production       3103  P2O5       2020  2020  tonnes
#
#          Value Flag Flag Description
# 240    38560.0    A  Official figure
# 241    52686.0    A  Official figure
# 242    58177.0    A  Official figure
# 243    59924.0    A  Official figure
# 244    55276.0    A  Official figure
# ...        ...  ...              ...
# 19735      0.0    I    Imputed value
# 19736      0.0    I    Imputed value
# 19737      0.0    I    Imputed value
# 19738      0.0    I    Imputed value
# 19739      0.0    I    Imputed value
#
# [1680 rows x 14 columns]

# %%
# Create a dictionary of DataFrames for each unique pair of Element and Item
groups = df.groupby(['Element', 'Item'])
dfs = {}
for name, group in groups:
    dfs[name] = group

# Print the contents of each DataFrame
for name, df in dfs.items():
    print(f"DataFrame for Element '{name[0]}' and Item '{name[1]}':")
    print(df)
# Out:
# DataFrame for Element 'Agricultural Use' and Item 'Nutrient nitrogen N (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 180           RFN  Fertilizers by Nutrient               40  Austria
# 181           RFN  Fertilizers by Nutrient               40  Austria
# 182           RFN  Fertilizers by Nutrient               40  Austria
# 183           RFN  Fertilizers by Nutrient               40  Austria
# 184           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19675         RFN  Fertilizers by Nutrient              752   Sweden
# 19676         RFN  Fertilizers by Nutrient              752   Sweden
# 19677         RFN  Fertilizers by Nutrient              752   Sweden
# 19678         RFN  Fertilizers by Nutrient              752   Sweden
# 19679         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code           Element  Item Code                         Item  \
# 180            5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 181            5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 182            5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 183            5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 184            5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# ...             ...               ...        ...                          ...
# 19675          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 19676          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 19677          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 19678          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 19679          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
#
#        Year Code  Year    Unit      Value Flag Flag Description
# 180         1961  1961  tonnes   52300.00    A  Official figure
# 181         1962  1962  tonnes   64239.00    A  Official figure
# 182         1963  1963  tonnes   68254.00    A  Official figure
# 183         1964  1964  tonnes   73380.00    A  Official figure
# 184         1965  1965  tonnes   91292.00    A  Official figure
# ...          ...   ...     ...        ...  ...              ...
# 19675       2016  2016  tonnes  186042.81    A  Official figure
# 19676       2017  2017  tonnes  198459.65    A  Official figure
# 19677       2018  2018  tonnes  184187.00    A  Official figure
# 19678       2019  2019  tonnes  182664.00    A  Official figure
# 19679       2020  2020  tonnes  215171.00    A  Official figure
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Agricultural Use' and Item 'Nutrient phosphate P2O5 (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 420           RFN  Fertilizers by Nutrient               40  Austria
# 421           RFN  Fertilizers by Nutrient               40  Austria
# 422           RFN  Fertilizers by Nutrient               40  Austria
# 423           RFN  Fertilizers by Nutrient               40  Austria
# 424           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19915         RFN  Fertilizers by Nutrient              752   Sweden
# 19916         RFN  Fertilizers by Nutrient              752   Sweden
# 19917         RFN  Fertilizers by Nutrient              752   Sweden
# 19918         RFN  Fertilizers by Nutrient              752   Sweden
# 19919         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code           Element  Item Code  \
# 420            5157  Agricultural Use       3103
# 421            5157  Agricultural Use       3103
# 422            5157  Agricultural Use       3103
# 423            5157  Agricultural Use       3103
# 424            5157  Agricultural Use       3103
# ...             ...               ...        ...
# 19915          5157  Agricultural Use       3103
# 19916          5157  Agricultural Use       3103
# 19917          5157  Agricultural Use       3103
# 19918          5157  Agricultural Use       3103
# 19919          5157  Agricultural Use       3103
#
#                                   Item  Year Code  Year    Unit      Value  \
# 420    Nutrient phosphate P2O5 (total)       1961  1961  tonnes  100207.00
# 421    Nutrient phosphate P2O5 (total)       1962  1962  tonnes  115353.00
# 422    Nutrient phosphate P2O5 (total)       1963  1963  tonnes  125687.00
# 423    Nutrient phosphate P2O5 (total)       1964  1964  tonnes  126262.00
# 424    Nutrient phosphate P2O5 (total)       1965  1965  tonnes  131070.00
# ...                                ...        ...   ...     ...        ...
# 19915  Nutrient phosphate P2O5 (total)       2016  2016  tonnes   30029.00
# 19916  Nutrient phosphate P2O5 (total)       2017  2017  tonnes   32954.64
# 19917  Nutrient phosphate P2O5 (total)       2018  2018  tonnes   32721.00
# 19918  Nutrient phosphate P2O5 (total)       2019  2019  tonnes   29409.00
# 19919  Nutrient phosphate P2O5 (total)       2020  2020  tonnes   38110.00
#
#       Flag Flag Description
# 420      A  Official figure
# 421      A  Official figure
# 422      A  Official figure
# 423      A  Official figure
# 424      A  Official figure
# ...    ...              ...
# 19915    A  Official figure
# 19916    A  Official figure
# 19917    A  Official figure
# 19918    A  Official figure
# 19919    A  Official figure
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Agricultural Use' and Item 'Nutrient potash K2O (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 660           RFN  Fertilizers by Nutrient               40  Austria
# 661           RFN  Fertilizers by Nutrient               40  Austria
# 662           RFN  Fertilizers by Nutrient               40  Austria
# 663           RFN  Fertilizers by Nutrient               40  Austria
# 664           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 20155         RFN  Fertilizers by Nutrient              752   Sweden
# 20156         RFN  Fertilizers by Nutrient              752   Sweden
# 20157         RFN  Fertilizers by Nutrient              752   Sweden
# 20158         RFN  Fertilizers by Nutrient              752   Sweden
# 20159         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code           Element  Item Code                         Item  \
# 660            5157  Agricultural Use       3104  Nutrient potash K2O (total)
# 661            5157  Agricultural Use       3104  Nutrient potash K2O (total)
# 662            5157  Agricultural Use       3104  Nutrient potash K2O (total)
# 663            5157  Agricultural Use       3104  Nutrient potash K2O (total)
# 664            5157  Agricultural Use       3104  Nutrient potash K2O (total)
# ...             ...               ...        ...                          ...
# 20155          5157  Agricultural Use       3104  Nutrient potash K2O (total)
# 20156          5157  Agricultural Use       3104  Nutrient potash K2O (total)
# 20157          5157  Agricultural Use       3104  Nutrient potash K2O (total)
# 20158          5157  Agricultural Use       3104  Nutrient potash K2O (total)
# 20159          5157  Agricultural Use       3104  Nutrient potash K2O (total)
#
#        Year Code  Year    Unit     Value Flag Flag Description
# 660         1961  1961  tonnes   99000.0    A  Official figure
# 661         1962  1962  tonnes  110593.0    A  Official figure
# 662         1963  1963  tonnes  132063.0    A  Official figure
# 663         1964  1964  tonnes  146830.0    A  Official figure
# 664         1965  1965  tonnes  140918.0    A  Official figure
# ...          ...   ...     ...       ...  ...              ...
# 20155       2016  2016  tonnes   35077.0    A  Official figure
# 20156       2017  2017  tonnes   36791.0    A  Official figure
# 20157       2018  2018  tonnes   38985.0    A  Official figure
# 20158       2019  2019  tonnes   36070.0    A  Official figure
# 20159       2020  2020  tonnes   43652.0    A  Official figure
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Export Quantity' and Item 'Nutrient nitrogen N (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 120           RFN  Fertilizers by Nutrient               40  Austria
# 121           RFN  Fertilizers by Nutrient               40  Austria
# 122           RFN  Fertilizers by Nutrient               40  Austria
# 123           RFN  Fertilizers by Nutrient               40  Austria
# 124           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19615         RFN  Fertilizers by Nutrient              752   Sweden
# 19616         RFN  Fertilizers by Nutrient              752   Sweden
# 19617         RFN  Fertilizers by Nutrient              752   Sweden
# 19618         RFN  Fertilizers by Nutrient              752   Sweden
# 19619         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code          Element  Item Code                         Item  \
# 120            5910  Export Quantity       3102  Nutrient nitrogen N (total)
# 121            5910  Export Quantity       3102  Nutrient nitrogen N (total)
# 122            5910  Export Quantity       3102  Nutrient nitrogen N (total)
# 123            5910  Export Quantity       3102  Nutrient nitrogen N (total)
# 124            5910  Export Quantity       3102  Nutrient nitrogen N (total)
# ...             ...              ...        ...                          ...
# 19615          5910  Export Quantity       3102  Nutrient nitrogen N (total)
# 19616          5910  Export Quantity       3102  Nutrient nitrogen N (total)
# 19617          5910  Export Quantity       3102  Nutrient nitrogen N (total)
# 19618          5910  Export Quantity       3102  Nutrient nitrogen N (total)
# 19619          5910  Export Quantity       3102  Nutrient nitrogen N (total)
#
#        Year Code  Year    Unit      Value Flag Flag Description
# 120         1961  1961  tonnes  128230.00    A  Official figure
# 121         1962  1962  tonnes  115574.00    A  Official figure
# 122         1963  1963  tonnes  101794.00    A  Official figure
# 123         1964  1964  tonnes  100430.00    A  Official figure
# 124         1965  1965  tonnes  121960.00    A  Official figure
# ...          ...   ...     ...        ...  ...              ...
# 19615       2016  2016  tonnes  101204.99    E  Estimated value
# 19616       2017  2017  tonnes  108767.64    E  Estimated value
# 19617       2018  2018  tonnes  118129.72    E  Estimated value
# 19618       2019  2019  tonnes   34328.29    E  Estimated value
# 19619       2020  2020  tonnes   76269.86    E  Estimated value
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Export Quantity' and Item 'Nutrient phosphate P2O5 (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 360           RFN  Fertilizers by Nutrient               40  Austria
# 361           RFN  Fertilizers by Nutrient               40  Austria
# 362           RFN  Fertilizers by Nutrient               40  Austria
# 363           RFN  Fertilizers by Nutrient               40  Austria
# 364           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19855         RFN  Fertilizers by Nutrient              752   Sweden
# 19856         RFN  Fertilizers by Nutrient              752   Sweden
# 19857         RFN  Fertilizers by Nutrient              752   Sweden
# 19858         RFN  Fertilizers by Nutrient              752   Sweden
# 19859         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code          Element  Item Code  \
# 360            5910  Export Quantity       3103
# 361            5910  Export Quantity       3103
# 362            5910  Export Quantity       3103
# 363            5910  Export Quantity       3103
# 364            5910  Export Quantity       3103
# ...             ...              ...        ...
# 19855          5910  Export Quantity       3103
# 19856          5910  Export Quantity       3103
# 19857          5910  Export Quantity       3103
# 19858          5910  Export Quantity       3103
# 19859          5910  Export Quantity       3103
#
#                                   Item  Year Code  Year    Unit    Value Flag  \
# 360    Nutrient phosphate P2O5 (total)       1961  1961     NaN      NaN  NaN
# 361    Nutrient phosphate P2O5 (total)       1962  1962     NaN      NaN  NaN
# 362    Nutrient phosphate P2O5 (total)       1963  1963  tonnes  1512.00    A
# 363    Nutrient phosphate P2O5 (total)       1964  1964  tonnes    70.00    A
# 364    Nutrient phosphate P2O5 (total)       1965  1965  tonnes  1190.00    A
# ...                                ...        ...   ...     ...      ...  ...
# 19855  Nutrient phosphate P2O5 (total)       2016  2016  tonnes  1316.90    E
# 19856  Nutrient phosphate P2O5 (total)       2017  2017  tonnes  1363.16    E
# 19857  Nutrient phosphate P2O5 (total)       2018  2018  tonnes  1757.15    E
# 19858  Nutrient phosphate P2O5 (total)       2019  2019  tonnes  1574.23    E
# 19859  Nutrient phosphate P2O5 (total)       2020  2020  tonnes  2567.18    E
#
#       Flag Description
# 360                NaN
# 361                NaN
# 362    Official figure
# 363    Official figure
# 364    Official figure
# ...                ...
# 19855  Estimated value
# 19856  Estimated value
# 19857  Estimated value
# 19858  Estimated value
# 19859  Estimated value
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Export Quantity' and Item 'Nutrient potash K2O (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 600           RFN  Fertilizers by Nutrient               40  Austria
# 601           RFN  Fertilizers by Nutrient               40  Austria
# 602           RFN  Fertilizers by Nutrient               40  Austria
# 603           RFN  Fertilizers by Nutrient               40  Austria
# 604           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 20095         RFN  Fertilizers by Nutrient              752   Sweden
# 20096         RFN  Fertilizers by Nutrient              752   Sweden
# 20097         RFN  Fertilizers by Nutrient              752   Sweden
# 20098         RFN  Fertilizers by Nutrient              752   Sweden
# 20099         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code          Element  Item Code                         Item  \
# 600            5910  Export Quantity       3104  Nutrient potash K2O (total)
# 601            5910  Export Quantity       3104  Nutrient potash K2O (total)
# 602            5910  Export Quantity       3104  Nutrient potash K2O (total)
# 603            5910  Export Quantity       3104  Nutrient potash K2O (total)
# 604            5910  Export Quantity       3104  Nutrient potash K2O (total)
# ...             ...              ...        ...                          ...
# 20095          5910  Export Quantity       3104  Nutrient potash K2O (total)
# 20096          5910  Export Quantity       3104  Nutrient potash K2O (total)
# 20097          5910  Export Quantity       3104  Nutrient potash K2O (total)
# 20098          5910  Export Quantity       3104  Nutrient potash K2O (total)
# 20099          5910  Export Quantity       3104  Nutrient potash K2O (total)
#
#        Year Code  Year    Unit     Value Flag Flag Description
# 600         1961  1961     NaN       NaN  NaN              NaN
# 601         1962  1962     NaN       NaN  NaN              NaN
# 602         1963  1963     NaN       NaN  NaN              NaN
# 603         1964  1964     NaN       NaN  NaN              NaN
# 604         1965  1965     NaN       NaN  NaN              NaN
# ...          ...   ...     ...       ...  ...              ...
# 20095       2016  2016  tonnes  58490.29    E  Estimated value
# 20096       2017  2017  tonnes  61434.48    E  Estimated value
# 20097       2018  2018  tonnes  61628.23    E  Estimated value
# 20098       2019  2019  tonnes  60636.48    E  Estimated value
# 20099       2020  2020  tonnes  63539.41    E  Estimated value
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Import Quantity' and Item 'Nutrient nitrogen N (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 60            RFN  Fertilizers by Nutrient               40  Austria
# 61            RFN  Fertilizers by Nutrient               40  Austria
# 62            RFN  Fertilizers by Nutrient               40  Austria
# 63            RFN  Fertilizers by Nutrient               40  Austria
# 64            RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19555         RFN  Fertilizers by Nutrient              752   Sweden
# 19556         RFN  Fertilizers by Nutrient              752   Sweden
# 19557         RFN  Fertilizers by Nutrient              752   Sweden
# 19558         RFN  Fertilizers by Nutrient              752   Sweden
# 19559         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code          Element  Item Code                         Item  \
# 60             5610  Import Quantity       3102  Nutrient nitrogen N (total)
# 61             5610  Import Quantity       3102  Nutrient nitrogen N (total)
# 62             5610  Import Quantity       3102  Nutrient nitrogen N (total)
# 63             5610  Import Quantity       3102  Nutrient nitrogen N (total)
# 64             5610  Import Quantity       3102  Nutrient nitrogen N (total)
# ...             ...              ...        ...                          ...
# 19555          5610  Import Quantity       3102  Nutrient nitrogen N (total)
# 19556          5610  Import Quantity       3102  Nutrient nitrogen N (total)
# 19557          5610  Import Quantity       3102  Nutrient nitrogen N (total)
# 19558          5610  Import Quantity       3102  Nutrient nitrogen N (total)
# 19559          5610  Import Quantity       3102  Nutrient nitrogen N (total)
#
#        Year Code  Year    Unit      Value Flag Flag Description
# 60          1961  1961  tonnes     826.00    A  Official figure
# 61          1962  1962  tonnes     779.00    A  Official figure
# 62          1963  1963  tonnes     633.00    A  Official figure
# 63          1964  1964  tonnes     602.00    A  Official figure
# 64          1965  1965  tonnes     892.00    A  Official figure
# ...          ...   ...     ...        ...  ...              ...
# 19555       2016  2016  tonnes  236754.63    E  Estimated value
# 19556       2017  2017  tonnes  240407.09    E  Estimated value
# 19557       2018  2018  tonnes  238974.17    E  Estimated value
# 19558       2019  2019  tonnes  246363.26    E  Estimated value
# 19559       2020  2020  tonnes  261030.41    E  Estimated value
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Import Quantity' and Item 'Nutrient phosphate P2O5 (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 300           RFN  Fertilizers by Nutrient               40  Austria
# 301           RFN  Fertilizers by Nutrient               40  Austria
# 302           RFN  Fertilizers by Nutrient               40  Austria
# 303           RFN  Fertilizers by Nutrient               40  Austria
# 304           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19795         RFN  Fertilizers by Nutrient              752   Sweden
# 19796         RFN  Fertilizers by Nutrient              752   Sweden
# 19797         RFN  Fertilizers by Nutrient              752   Sweden
# 19798         RFN  Fertilizers by Nutrient              752   Sweden
# 19799         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code          Element  Item Code  \
# 300            5610  Import Quantity       3103
# 301            5610  Import Quantity       3103
# 302            5610  Import Quantity       3103
# 303            5610  Import Quantity       3103
# 304            5610  Import Quantity       3103
# ...             ...              ...        ...
# 19795          5610  Import Quantity       3103
# 19796          5610  Import Quantity       3103
# 19797          5610  Import Quantity       3103
# 19798          5610  Import Quantity       3103
# 19799          5610  Import Quantity       3103
#
#                                   Item  Year Code  Year    Unit     Value  \
# 300    Nutrient phosphate P2O5 (total)       1961  1961  tonnes  57745.00
# 301    Nutrient phosphate P2O5 (total)       1962  1962  tonnes  65581.00
# 302    Nutrient phosphate P2O5 (total)       1963  1963  tonnes  70181.00
# 303    Nutrient phosphate P2O5 (total)       1964  1964  tonnes  67781.00
# 304    Nutrient phosphate P2O5 (total)       1965  1965  tonnes  68426.00
# ...                                ...        ...   ...     ...       ...
# 19795  Nutrient phosphate P2O5 (total)       2016  2016  tonnes  49989.57
# 19796  Nutrient phosphate P2O5 (total)       2017  2017  tonnes  60888.77
# 19797  Nutrient phosphate P2O5 (total)       2018  2018  tonnes  58270.19
# 19798  Nutrient phosphate P2O5 (total)       2019  2019  tonnes  55283.97
# 19799  Nutrient phosphate P2O5 (total)       2020  2020  tonnes  65297.92
#
#       Flag Flag Description
# 300      A  Official figure
# 301      A  Official figure
# 302      A  Official figure
# 303      A  Official figure
# 304      A  Official figure
# ...    ...              ...
# 19795    E  Estimated value
# 19796    E  Estimated value
# 19797    E  Estimated value
# 19798    E  Estimated value
# 19799    E  Estimated value
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Import Quantity' and Item 'Nutrient potash K2O (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 540           RFN  Fertilizers by Nutrient               40  Austria
# 541           RFN  Fertilizers by Nutrient               40  Austria
# 542           RFN  Fertilizers by Nutrient               40  Austria
# 543           RFN  Fertilizers by Nutrient               40  Austria
# 544           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 20035         RFN  Fertilizers by Nutrient              752   Sweden
# 20036         RFN  Fertilizers by Nutrient              752   Sweden
# 20037         RFN  Fertilizers by Nutrient              752   Sweden
# 20038         RFN  Fertilizers by Nutrient              752   Sweden
# 20039         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code          Element  Item Code                         Item  \
# 540            5610  Import Quantity       3104  Nutrient potash K2O (total)
# 541            5610  Import Quantity       3104  Nutrient potash K2O (total)
# 542            5610  Import Quantity       3104  Nutrient potash K2O (total)
# 543            5610  Import Quantity       3104  Nutrient potash K2O (total)
# 544            5610  Import Quantity       3104  Nutrient potash K2O (total)
# ...             ...              ...        ...                          ...
# 20035          5610  Import Quantity       3104  Nutrient potash K2O (total)
# 20036          5610  Import Quantity       3104  Nutrient potash K2O (total)
# 20037          5610  Import Quantity       3104  Nutrient potash K2O (total)
# 20038          5610  Import Quantity       3104  Nutrient potash K2O (total)
# 20039          5610  Import Quantity       3104  Nutrient potash K2O (total)
#
#        Year Code  Year    Unit      Value Flag Flag Description
# 540         1961  1961  tonnes   99184.00    A  Official figure
# 541         1962  1962  tonnes  114223.00    A  Official figure
# 542         1963  1963  tonnes  143552.00    A  Official figure
# 543         1964  1964  tonnes  167014.00    A  Official figure
# 544         1965  1965  tonnes  158322.00    A  Official figure
# ...          ...   ...     ...        ...  ...              ...
# 20035       2016  2016  tonnes  119803.29    E  Estimated value
# 20036       2017  2017  tonnes  141596.58    E  Estimated value
# 20037       2018  2018  tonnes  131416.16    E  Estimated value
# 20038       2019  2019  tonnes  126151.07    E  Estimated value
# 20039       2020  2020  tonnes  136916.03    E  Estimated value
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Production' and Item 'Nutrient nitrogen N (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 0             RFN  Fertilizers by Nutrient               40  Austria
# 1             RFN  Fertilizers by Nutrient               40  Austria
# 2             RFN  Fertilizers by Nutrient               40  Austria
# 3             RFN  Fertilizers by Nutrient               40  Austria
# 4             RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19495         RFN  Fertilizers by Nutrient              752   Sweden
# 19496         RFN  Fertilizers by Nutrient              752   Sweden
# 19497         RFN  Fertilizers by Nutrient              752   Sweden
# 19498         RFN  Fertilizers by Nutrient              752   Sweden
# 19499         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code     Element  Item Code                         Item  \
# 0              5510  Production       3102  Nutrient nitrogen N (total)
# 1              5510  Production       3102  Nutrient nitrogen N (total)
# 2              5510  Production       3102  Nutrient nitrogen N (total)
# 3              5510  Production       3102  Nutrient nitrogen N (total)
# 4              5510  Production       3102  Nutrient nitrogen N (total)
# ...             ...         ...        ...                          ...
# 19495          5510  Production       3102  Nutrient nitrogen N (total)
# 19496          5510  Production       3102  Nutrient nitrogen N (total)
# 19497          5510  Production       3102  Nutrient nitrogen N (total)
# 19498          5510  Production       3102  Nutrient nitrogen N (total)
# 19499          5510  Production       3102  Nutrient nitrogen N (total)
#
#        Year Code  Year    Unit     Value Flag Flag Description
# 0           1961  1961  tonnes  172380.0    A  Official figure
# 1           1962  1962  tonnes  173422.0    A  Official figure
# 2           1963  1963  tonnes  169812.0    A  Official figure
# 3           1964  1964  tonnes  184900.0    A  Official figure
# 4           1965  1965  tonnes  211070.0    A  Official figure
# ...          ...   ...     ...       ...  ...              ...
# 19495       2016  2016  tonnes       0.0    I    Imputed value
# 19496       2017  2017  tonnes       0.0    I    Imputed value
# 19497       2018  2018  tonnes       0.0    I    Imputed value
# 19498       2019  2019  tonnes       0.0    I    Imputed value
# 19499       2020  2020  tonnes       0.0    I    Imputed value
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Production' and Item 'Nutrient phosphate P2O5 (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 240           RFN  Fertilizers by Nutrient               40  Austria
# 241           RFN  Fertilizers by Nutrient               40  Austria
# 242           RFN  Fertilizers by Nutrient               40  Austria
# 243           RFN  Fertilizers by Nutrient               40  Austria
# 244           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19735         RFN  Fertilizers by Nutrient              752   Sweden
# 19736         RFN  Fertilizers by Nutrient              752   Sweden
# 19737         RFN  Fertilizers by Nutrient              752   Sweden
# 19738         RFN  Fertilizers by Nutrient              752   Sweden
# 19739         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code     Element  Item Code                             Item  \
# 240            5510  Production       3103  Nutrient phosphate P2O5 (total)
# 241            5510  Production       3103  Nutrient phosphate P2O5 (total)
# 242            5510  Production       3103  Nutrient phosphate P2O5 (total)
# 243            5510  Production       3103  Nutrient phosphate P2O5 (total)
# 244            5510  Production       3103  Nutrient phosphate P2O5 (total)
# ...             ...         ...        ...                              ...
# 19735          5510  Production       3103  Nutrient phosphate P2O5 (total)
# 19736          5510  Production       3103  Nutrient phosphate P2O5 (total)
# 19737          5510  Production       3103  Nutrient phosphate P2O5 (total)
# 19738          5510  Production       3103  Nutrient phosphate P2O5 (total)
# 19739          5510  Production       3103  Nutrient phosphate P2O5 (total)
#
#        Year Code  Year    Unit    Value Flag Flag Description
# 240         1961  1961  tonnes  38560.0    A  Official figure
# 241         1962  1962  tonnes  52686.0    A  Official figure
# 242         1963  1963  tonnes  58177.0    A  Official figure
# 243         1964  1964  tonnes  59924.0    A  Official figure
# 244         1965  1965  tonnes  55276.0    A  Official figure
# ...          ...   ...     ...      ...  ...              ...
# 19735       2016  2016  tonnes      0.0    I    Imputed value
# 19736       2017  2017  tonnes      0.0    I    Imputed value
# 19737       2018  2018  tonnes      0.0    I    Imputed value
# 19738       2019  2019  tonnes      0.0    I    Imputed value
# 19739       2020  2020  tonnes      0.0    I    Imputed value
#
# [1680 rows x 14 columns]
# DataFrame for Element 'Production' and Item 'Nutrient potash K2O (total)':
#       Domain Code                   Domain  Area Code (M49)     Area  \
# 480           RFN  Fertilizers by Nutrient               40  Austria
# 481           RFN  Fertilizers by Nutrient               40  Austria
# 482           RFN  Fertilizers by Nutrient               40  Austria
# 483           RFN  Fertilizers by Nutrient               40  Austria
# 484           RFN  Fertilizers by Nutrient               40  Austria
# ...           ...                      ...              ...      ...
# 19975         RFN  Fertilizers by Nutrient              752   Sweden
# 19976         RFN  Fertilizers by Nutrient              752   Sweden
# 19977         RFN  Fertilizers by Nutrient              752   Sweden
# 19978         RFN  Fertilizers by Nutrient              752   Sweden
# 19979         RFN  Fertilizers by Nutrient              752   Sweden
#
#        Element Code     Element  Item Code                         Item  \
# 480            5510  Production       3104  Nutrient potash K2O (total)
# 481            5510  Production       3104  Nutrient potash K2O (total)
# 482            5510  Production       3104  Nutrient potash K2O (total)
# 483            5510  Production       3104  Nutrient potash K2O (total)
# 484            5510  Production       3104  Nutrient potash K2O (total)
# ...             ...         ...        ...                          ...
# 19975          5510  Production       3104  Nutrient potash K2O (total)
# 19976          5510  Production       3104  Nutrient potash K2O (total)
# 19977          5510  Production       3104  Nutrient potash K2O (total)
# 19978          5510  Production       3104  Nutrient potash K2O (total)
# 19979          5510  Production       3104  Nutrient potash K2O (total)
#
#        Year Code  Year    Unit  Value Flag Flag Description
# 480         1961  1961     NaN    NaN  NaN              NaN
# 481         1962  1962     NaN    NaN  NaN              NaN
# 482         1963  1963     NaN    NaN  NaN              NaN
# 483         1964  1964     NaN    NaN  NaN              NaN
# 484         1965  1965     NaN    NaN  NaN              NaN
# ...          ...   ...     ...    ...  ...              ...
# 19975       2016  2016  tonnes    0.0    I    Imputed value
# 19976       2017  2017  tonnes    0.0    I    Imputed value
# 19977       2018  2018  tonnes    0.0    I    Imputed value
# 19978       2019  2019  tonnes    0.0    I    Imputed value
# 19979       2020  2020  tonnes    0.0    I    Imputed value
#
# [1680 rows x 14 columns]

# %%
dfs[1]
# Out:
# ----------------------
# KeyErrorTraceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1496\1633160854.py in <module>
# ----> 1 dfs[1]
#
# KeyError: 1

# %%
# Group the DataFrame by 'Element' and 'Item'
groups = df.groupby(['Element', 'Item'])

# %%
# Group the DataFrame by Element and Item
grouped = nutrient_df.groupby(['Element', 'Item'])

# %%
for name, group in groups:
    element, item = name
    filename = f"{element}_{item}.csv"
    group.to_csv(filename, index=False)

# %%
# Loop over each group and create a new DataFrame for each
for name, group in grouped:
    # Create a new DataFrame using the group
    new_df = pd.DataFrame(group)

# %%
# Create an empty dictionary to store the new DataFrames
dfs = {}

# Loop over each group and create a new DataFrame for each
for name, group in grouped:
    # Create a new DataFrame using the group
    new_df = pd.DataFrame(group)
    
    # Get the names of the Element and Item for this group
    element_name = name[0]
    item_name = name[1]
    
    # Create a unique name for this new DataFrame
    df_name = f'{element_name}_{item_name}_df'
    
    # Store the new DataFrame in the dictionary
    dfs[df_name] = new_df

dfs['Nitrogen_Fertilizers_df']
# Out:
# ----------------------
# KeyErrorTraceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1496\3602895833.py in <module>
#      17     dfs[df_name] = new_df
#      18
# ---> 19 dfs['Nitrogen_Fertilizers_df']
#
# KeyError: 'Nitrogen_Fertilizers_df'

# %%
    
    # Do EDA on the new DataFrame as desired
    # ...
    
    # Store the new DataFrame however you like (e.g. in a dictionary)
    # ...

# %%
# Group by country and item and calculate the mean value
df_grouped = dfs['Production_Crops_Economic'].groupby(['Area', 'Item']).mean()

# Print the first 5 rows
print(df_grouped.head())

# %%
"""We will bring in another predictor manually before automating
The unwanted area and years are filtered out by the process Next  LandCover """
os.listdir('./raw')
# Out:
# ['.ipynb_checkpoints',
#  'AnnualPopulation.csv',
#  'arch',
#  'beefandbuffalo.csv',
#  'ConsumerPriceIndices.csv',
#  'CropsAndlivestockCattleFeed.csv',
#  'Deflators.csv',
#  'DetailedTradeMatrix.csv',
#  'ExchangeRates.csv',
#  'FertilizersByNutrient.csv',
#  'grasslands.csv',
#  'LandCover.csv',
#  'LandUse.csv',
#  'LandUseIndicators.csv',
#  'land_pasture.csv',
#  'land_use_all_items_area_eu28.csv',
#  'Livestock Manure.csv',
#  'LivestockManure.csv',
#  'LivestockPatterns.csv',
#  'manure.csv',
#  'ManureManagement.csv',
#  'meat.csv',
#  'nutrient.csv',
#  'price.csv',
#  'ProducerPrices.csv',
#  'ProductionIndices.csv',
#  'pr_timeseries__IRL.csv',
#  'stocks.csv',
#  'tas_timeseries_IRL.csv',
#  'TCC-Metadata.csv',
#  'temperature_change.csv',
#  'temperature_sd.csv',
#  'TradeIndices.csv',
#  'ValueofAgricultural Production.csv',
#  'yield.csv']

# %% [markdown]
# predictor variables to include in the analysis.
# -  production volume
# - imports
# - exports and
# - slaughter numbers.

# %%
import pandas as pd

def read_data(file_path):
    # Read in the data
    df = pd.read_csv(file_path)
    return df

def clean_column_names(df):
    # Replace forward slashes, backslashes, and commas in column names with underscores
    df.columns = df.columns.str.replace('[/\\\\, (,) ,=  ]', '_')
    return df

def clean_element_item_values(df):
    # Replace forward slashes, backslashes, commas, periods, and hyphens in Element and Item values with underscores
    df['Element'] = df['Element'].str.replace('[/\\\\, (,) , =  ]', '_')
    df['Item'] = df['Item'].str.replace('[/\\\\, (,), =   -\.]', '_')
    return df


def drop_rows(df):
    # Drop rows where Area is 'Belgium-Luxembourg'
    df = df[df['Area'] != 'Belgium-Luxembourg']
    return df

def generate_key_column(df):
    # Merge Area and Year columns into a new Key column
    df['Key'] = df['Area'] + '_' + df['Year'].astype(str)
    return df

def filter_dataframes(df):
    # Generate a list of dataframes, with each dataframe filtered by Element and Item
    dfs = []
    for element in df['Element'].unique():
        for item in df['Item'].unique():
            element_item_df = df[(df['Element'] == element) & (df['Item'] == item)]
            if not element_item_df.empty:
                # Replace spaces and decimal points with underscores in dataframe names
                element_item_name = element.replace(' ', '_').replace('.', '_') + '_' + item.replace(' ', '_').replace('.', '_') + '_df'
                dfs.append(element_item_name)
                # Replace spaces and decimal points with underscores in dataframe variable names
                exec(element_item_name.replace(' ', '_').replace('.', '_') + ' = element_item_df')

    # Debugging line: print out the list of dataframe names
    print(dfs)
    
    # Return a dictionary of the dataframes
    return {name: globals()[name] for name in dfs}


def preprocess_data(file_path):
    df = read_data(file_path)
    df = drop_rows(df)
    df = clean_column_names(df)
    df = clean_element_item_values(df)
    return filter_dataframes(df)

#     df = generate_key_column(df)

# %%
# Group by element and item and calculate the mean value
df_grouped = dfs['Production_Crops_Economic'].groupby(['Area', 'Item']).mean()

# Print the first 5 rows
print(df_grouped.head())

# %%
dfs = preprocess_data('raw/nutrient.csv')
print(dfs.keys())
# Out:
# ['Production_Nutrient_nitrogen_N__total__df', 'Production_Nutrient_phosphate_P2O5__total__df', 'Production_Nutrient_potash_K2O__total__df', 'Import_Quantity_Nutrient_nitrogen_N__total__df', 'Import_Quantity_Nutrient_phosphate_P2O5__total__df', 'Import_Quantity_Nutrient_potash_K2O__total__df', 'Export_Quantity_Nutrient_nitrogen_N__total__df', 'Export_Quantity_Nutrient_phosphate_P2O5__total__df', 'Export_Quantity_Nutrient_potash_K2O__total__df', 'Agricultural_Use_Nutrient_nitrogen_N__total__df', 'Agricultural_Use_Nutrient_phosphate_P2O5__total__df', 'Agricultural_Use_Nutrient_potash_K2O__total__df']
# C:\Users\ronan\AppData\Local\Temp\ipykernel_1496\1677369424.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('[/\\\\, (,) ,=  ]', '_')
# C:\Users\ronan\AppData\Local\Temp\ipykernel_1496\1677369424.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Element'] = df['Element'].str.replace('[/\\\\, (,) , =  ]', '_')
# C:\Users\ronan\AppData\Local\Temp\ipykernel_1496\1677369424.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Item'] = df['Item'].str.replace('[/\\\\, (,), =   -\.]', '_')
# ----------------------
# KeyErrorTraceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1496\2569534582.py in <module>
# ----> 1 dfs = preprocess_data('raw/nutrient.csv')
#       2 print(dfs.keys())
#
# ~\AppData\Local\Temp\ipykernel_1496\1677369424.py in preprocess_data(file_path)
#      53     df = clean_column_names(df)
#      54     df = clean_element_item_values(df)
# ---> 55     return filter_dataframes(df)
#      56
#      57 #     df = generate_key_column(df)
#
# ~\AppData\Local\Temp\ipykernel_1496\1677369424.py in filter_dataframes(df)
#      45
#      46     # Return a dictionary of the dataframes
# ---> 47     return {name: globals()[name] for name in dfs}
#      48
#      49
#
# ~\AppData\Local\Temp\ipykernel_1496\1677369424.py in <dictcomp>(.0)
#      45
#      46     # Return a dictionary of the dataframes
# ---> 47     return {name: globals()[name] for name in dfs}
#      48
#      49
#
# KeyError: 'Production_Nutrient_nitrogen_N__total__df'

# %%
Yield_Carcass_Weight_Beef_and_Buffalo_Meat__primary_df
# Out:
# ----------------------
# NameErrorTraceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1496\2618469341.py in <module>
# ----> 1 Yield_Carcass_Weight_Beef_and_Buffalo_Meat__primary_df
#
# NameError: name 'Yield_Carcass_Weight_Beef_and_Buffalo_Meat__primary_df' is not defined

# %%
dfs = preprocess_data('raw/beefandbuffalo.csv')
print(dfs.keys())  # prints a list of the names of the processed dataframes
# Out:
# ['Yield_Carcass_Weight_Meat_of_cattle_with_the_bone__fresh_or_chilled_df', 'Yield_Carcass_Weight_Beef_and_Buffalo_Meat__primary_df', 'Yield_Carcass_Weight_Meat_of_buffalo__fresh_or_chilled_df', 'Production_Meat_of_cattle_with_the_bone__fresh_or_chilled_df', 'Production_Beef_and_Buffalo_Meat__primary_df', 'Production_Meat_of_buffalo__fresh_or_chilled_df', 'Producing_Animals_Slaughtered_Meat_of_cattle_with_the_bone__fresh_or_chilled_df', 'Producing_Animals_Slaughtered_Beef_and_Buffalo_Meat__primary_df', 'Producing_Animals_Slaughtered_Meat_of_buffalo__fresh_or_chilled_df']
# C:\Users\ronan\AppData\Local\Temp\ipykernel_1496\2130265054.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('[/\\\\, (,) ,=  ]', '_')
# C:\Users\ronan\AppData\Local\Temp\ipykernel_1496\2130265054.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Element'] = df['Element'].str.replace('[/\\\\, (,) , =  ]', '_')
# C:\Users\ronan\AppData\Local\Temp\ipykernel_1496\2130265054.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Item'] = df['Item'].str.replace('[/\\\\, (,), =   -\.]', '_')
# ----------------------
# KeyErrorTraceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1496\3548104727.py in <module>
# ----> 1 dfs = preprocess_data('raw/beefandbuffalo.csv')
#       2 print(dfs.keys())  # prints a list of the names of the processed dataframes
#
# ~\AppData\Local\Temp\ipykernel_1496\2130265054.py in preprocess_data(file_path)
#      54     df = drop_rows(df)
#      55     df = generate_key_column(df)
# ---> 56     return filter_dataframes(df)
#      57
#
# ~\AppData\Local\Temp\ipykernel_1496\2130265054.py in filter_dataframes(df)
#      45
#      46     # Return a dictionary of the dataframes
# ---> 47     return {name: globals()[name] for name in dfs}
#      48
#      49
#
# ~\AppData\Local\Temp\ipykernel_1496\2130265054.py in <dictcomp>(.0)
#      45
#      46     # Return a dictionary of the dataframes
# ---> 47     return {name: globals()[name] for name in dfs}
#      48
#      49
#
# KeyError: 'Yield_Carcass_Weight_Meat_of_cattle_with_the_bone__fresh_or_chilled_df'

# %%
Yield_Carcass_Weight_Meat_of_cattle_with_the_bone__fresh_or_chilled_df
# Out:
# ----------------------
# NameErrorTraceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1496\4036762560.py in <module>
# ----> 1 Yield_Carcass_Weight_Meat_of_cattle_with_the_bone__fresh_or_chilled_df
#
# NameError: name 'Yield_Carcass_Weight_Meat_of_cattle_with_the_bone__fresh_or_chilled_df' is not defined

# %%
def preprocess_data(file_path):
    # Read in the data
    df = pd.read_csv(file_path)

    # Replace forward slashes, backslashes, and commas in column names with underscores
    df.columns = df.columns.str.replace('[/\\\\, ]', '_')

    # Replace forward slashes, backslashes, and commas in Element and Item values with underscores
    df['Element'] = df['Element'].str.replace('[/\\\\, ]', '_')
    df['Item'] = df['Item'].str.replace('[/\\\\, ]', '_')

    # Drop rows where Area is 'Belgium-Luxembourg'
    df = df[df['Area'] != 'Belgium-Luxembourg']

    # Merge Area and Year columns into a new Key column
    df['Key'] = df['Area'] + '_' + df['Year'].astype(str)

    # Generate a list of dataframes, with each dataframe filtered by Element and Item
    dfs = []
    for element in df['Element'].unique():
        for item in df['Item'].unique():
            element_item_df = df[(df['Element'] == element) & (df['Item'] == item)]
            if not element_item_df.empty:
                # Replace spaces with underscores in dataframe names
                element_item_name = element + '_' + item.replace(' ', '_') + '_df'
                dfs.append(element_item_name)
                # Replace spaces with underscores in dataframe variable names
                exec(element_item_name.replace(' ', '_') + ' = element_item_df')

    # Return a dictionary of the dataframes
    return {name: globals()[name] for name in dfs}

# %%
YiCaMe_df=Yield_Carcass_Weight_Meat_of_cattle_with_the_bone__fresh_or_chilled_df

YiCaMe_df

# %%
beefandbuffalo_df = pd.read_csv( 'raw/beefandbuffalo.csv', on_bad_lines='skip')   # loads Land USe Domain
beefandbuffalo_df.head(5)

# %%
dfs = create_dfs(beefandbuffalo_df)
df_names = [name for name, _ in dfs]
df_names

# %%
Producing_Animals_Slaughtered_Beef_and_Buffalo_Meat__primary_df.head()

# %%
df_list = group_by_element_item(beefandbuffalo_df)

# loop over the list and print the name of each dataframe and its first few rows
for i, df in enumerate(df_list):
    print(f"Dataframe {i}: {df.columns[0]} - {df.columns[1]}")
    print(df.head())
    print()

# %%
Dataframe 1

# %%
# iterate over the groups and create new dataframes
for group_name, group_data in grouped_df:
    # create a new dataframe with the group data
    new_df = group_data.copy()

    # append the new dataframe to the list
    df_list.append(new_df)

    # print the first few rows of the new dataframe
    print("New dataframe created: ", group_name)
    new_df.head()

# %%
Production=df_list[1]
Production
# assuming the dataframe is called 'Production'
unique_items = Production['Item'].unique()
print(unique_items)

# %%
# 
grouped_df = beefandbuffalo_df.groupby('Element')

# %%
# iterate over the groups and create new dataframes
for group_name, group_data in grouped_df:
    # create a new dataframe with the group data
    new_df_name = group_name + "_df"
    locals()[new_df_name] = group_data

# %%
# assuming the original dataframe is called 'df'
grouped_df = df.groupby('Element')
df_list = []

# %%
    # print the first few rows of the new dataframe
    print("New dataframe created: ", new_df_name)
    print(locals()[new_df_name].head())

# %%
def filters(df):
    # Delete the "Belgium-Luxembourg" column
    if "Belgium-Luxembourg" in df.columns:
        df = df.drop("Belgium-Luxembourg", axis=1)

    # Filter the "Year" column to only include years greater than or equal to 2000
    df = df[df["Year"] >= 2000]

    return df

# %%
# Get a list of unique countries from the "Area" column
countries = df['Area'].unique()
countries

# %%
# count the number of missing values in each column
missing_values = df.isnull().sum()

# print the result
print(missing_values)

# %%
# Count the number of areas with missing values
num_missing_areas = df['Area'][df.isna().any(axis=1)].nunique()

# Print the result
print("The number of areas with missing values is:", num_missing_areas)

# %%
31900/1708 # 20% data is missing

# %%
df.shape

# %%
snake('Distribution of Missing Values by Area')

# %%
snake('msno.matrix(df)')

# %%
msno.matrix(df)

# %%
# create a bar chart of the missing value counts by year
plt.figure(figsize=(20,8))  # increase the figure size for better readability
ax = year_counts.plot(kind='bar')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Missing Values', fontsize=14)
plt.title('Distribution of Missing Values by Year', fontsize=18)
plt.xticks(rotation=0, fontsize=12)  # rotate x-axis labels to 0 degrees
ax.tick_params(axis='y', labelsize=12)  # adjust y-axis label size
ax.tick_params(axis='x', pad=10)  # adjust x-axis tick padding

# add value labels to the bars
for i, v in enumerate(year_counts):
    ax.text(i, v, str(v), ha='center', va='bottom', fontweight='bold', fontsize=12)

# set year labels vertically
ax.set_xticklabels(year_counts.index, rotation=90)

plt.show()

# %%
""" 
A new dataframe with counts of missing values 
for each country was sorted in descending order
revealing  the top 10 countries

"""


# create a new dataframe to hold the counts of missing values by country
country_counts = df.isnull().sum(axis=1).groupby(df.Area).sum().sort_values(ascending=False)

# get the top 10 countries with the most missing values
top_10_countries = country_counts.head(10)

# print the list of top 10 countries
print(top_10_countries)

# %%
# create a new dataframe to hold the counts of missing values by country
country_counts = df.isnull().sum(axis=1).groupby(df.Area).sum().sort_values(ascending=True)

# get the list of countries with any missing values
missing_countries = country_counts[country_counts > 0].index

# print the list of countries with missing values
print("Countries with missing values:\n", missing_countries)

# %%
# create a new dataframe to hold the counts of missing values by country
country_counts = df.isnull().sum(axis=1).groupby(df.Area).sum().sort_values(ascending=True)

# get the list of countries with any missing values
missing_countries = country_counts[country_counts > 0].index

# print the list of countries with missing values
print("Countries with missing values:\n", missing_countries)

# %%
# create a new dataframe to hold the counts of missing values by country
country_counts = df.isnull().sum(axis=1).groupby(df.Area).sum().sort_values(ascending=True)

# get the list of countries with any missing values
missing_countries = country_counts[country_counts > 0]

# create a new dataframe with the missing value counts and the total number of observations for each country
mv_counts = pd.concat([missing_countries, df.groupby('Area').size()], axis=1)
mv_counts.columns = ['Missing Values', 'Total Observations']

# calculate the proportion of missing values for each country
mv_counts['% Missing'] = mv_counts['Missing Values'] / mv_counts['Total Observations'] * 100

# sort the dataframe by the proportion of missing values in descending order
mv_counts = mv_counts.sort_values('% Missing', ascending=False)

# display the table
print(mv_counts.to_string())

# %%
# group the data by Area and compute the total count of missing values for each group
area_counts = df.isnull().sum(axis=1).groupby(df.Area).sum()

# create a bar chart of the missing value counts by Area
plt.figure(figsize=(10,5))
ax = area_counts.plot(kind='bar')
plt.xlabel('Area')
plt.ylabel('Number of Missing Values')
plt.title('Distribution of Missing Values by Area')
plt.xticks(rotation=45)

# add value labels to the bars
for i, v in enumerate(area_counts):
    ax.text(i, v, str(v), ha='center', va='bottom', fontweight='bold')

plt.show()

# %%
df.dtypes

# %%
"""
#### Title 
The 'title' naming convention is where each word starts
with a capital letter, except for prepositions and conjunctions, which start with a lowercase letter. 
The function takes a string as input and converts it to title case, 
where the first letter of each non-conjunction/preposition word is capitalized, and all other letters are lowercase.
It achieves this by splitting the input string into a list of words, identifying which words are prepositions or conjunctions based on a predefined list, and then capitalizing the first letter of all other words while converting prepositions and conjunctions to lowercase. The resulting list of processed words is then joined back into a single string with proper spacing and returned.
"""
def title(sentence):
    """
    Takes a string and converts it to title case, where the first letter of each
    non-conjunction/preposition word is capitalized, and all other letters are lowercase.
    
    Args:
        sentence (str): The string to convert to title case.
        
    Returns:
        str: The input string converted to title case.
    """
    # Define a list of common prepositions and conjunctions
    prepositions_conjunctions = ['a', 'this', 'an', 'the', 'and', 'but', 'or', 'for', 'has', 'nor', 'on', 'at', 'to', 'from', 'by', 'over', 'under', 'in', 'out', 'of']
    # Split the input string into a list of words
    words = sentence.split()
    processed_words = []
    for word in words:
        # If the word is not a preposition or conjunction, capitalize the first letter and lowercase the rest
        if word.lower() not in prepositions_conjunctions:
            processed_words.append(word.capitalize())
        # If the word is a preposition or conjunction, convert to lowercase
        else:
            processed_words.append(word.lower())
    # Join the list of processed words into a single string, with proper spacing
    output = " ".join(processed_words)
    # Remove any leading/trailing whitespace and add some padding
    return "     " + re.sub('\s+', ' ', output.strip()) + "     "

# %%
unique_describtions = df['Flag Description'].unique()
print(unique_describtions)

# %%
df

# %%
df= df[df['Year'] > 1999]

# %%
df.sample(11)

# %%
df['Key'] = df['Area'] + '_' + df['Year'].astype(str)

# %%
df.sample(22)

# %%
flag_values = df['Flag Description'].unique()
print(flag_values)

# %%
df = df.drop(['Domain Code', 'Domain', 'Area Code (M49)', 'Element Code', 'Element', 'Item Code (CPC)', 'Year Code', 'Year', 'Unit', 'Flag Description'], axis=1)

# %%
import matplotlib.pyplot as plt

# count the frequency of NaN and 'Official figure' values in the 'Flag Description' column
flag_counts = df['Flag Description'].value_counts(dropna=False)

# plot a pie chart of the flag counts
plt.figure(figsize=(6, 6))
plt.pie(flag_counts, labels=flag_counts.index, autopct='%1.1f%%')
plt.title('Flag Description Frequencies')
plt.show()

# %%
nan_countries = df[df.isna().any(axis=1)]['Area'].unique()

print(nan_countries)

# %%
unique_areas = df['Area'].unique()
print(unique_areas)

# %%
bl_data = df[df['Area'] == 'Belgium-Luxembourg']
bl_data.head(60)

# %%
luxembourg_data = df[df["Area"] == "Luxembourg"]

# %%
df[df["Area"] == "Luxembourg"].head(70)

# %%
df[df['Area'] == 'Belgium'].head(60)

# %%
num_areas = df['Area'].nunique()
print('Number of unique areas:', num_areas)

# %%
# drop rows for Belgium-Luxembourg
df = df.drop(index=df[df["Area"] == "Belgium-Luxembourg"].index)

# %%
df.head(60)

# %%
"""
removeing extraneous columns
"""

df = df.drop(['flag','Domain Code', 'Domain', 'Area Code (M49)', 'Element Code', 'Element', 'Item Code (CPC)', 'Year Code', 'Year', 'Unit', 'Flag Description'], axis=1)

# %%
snake('"This is a text with periods. (And other characters.)"')

# %% [markdown]
# ####  Pascal
# The 'pascal' naming function takes in a string as input and converts it to a PascalCase format. PascalCase is a naming convention where the first letter of each word is capitalized, and there are no spaces or separators between the words.

# %%
def pascal(string):
    """
    Convert a space- or snake-separated string to PascalCase.

    Parameters:
        string (str): The input string to convert to PascalCase.

    Returns:
        str: The input string in PascalCase format.

    """
    # Replace any underscores with spaces
    string = string.replace("_", " ")
    # Capitalize the first letter of each word
    words = string.title()
    # Remove any remaining spaces
    words = words.replace(" ", "")
    return words

# %%
"""
#### Camel

Camel case is a naming convention in which each word in a compound word is capitalized, except for the first word which is in lower case. It is commonly used in programming languages for naming variables and functions.

handles both snake_case and space-separated strings
"""
def camel(string):
    """
    Convert a space-separated or snake_case string to camelCase.

    Parameters:
        string (str): The string to convert.

    Returns:
        str: The converted string in camelCase.
    """
    # Replace underscores with spaces and split the string into a list of words
    words = string.replace("_", " ").split()
    # Convert the first word to lowercase and capitalize all subsequent words
    camel_cased = [words[0].lower()] + [word.capitalize() for word in words[1:]]
    # Concatenate the words together and return the resulting string
    return "    " + ''.join(camel_cased) + "    "

# %%
def delete(file_name):
    file_path = os.path.join("..", "data", "raw", file_name)
    expected_ext = ".csv"
    if not file_path.endswith(expected_ext):
        print("Error: Invalid file extension. File extension must be .csv.")
    elif os.path.exists(file_path):
        os.remove(file_path)
        print(f"{file_name} deleted successfully")
    else:
        print(f"{file_name} not found")

# %% [markdown]
# #### Rename
#
# This function first constructs the file_path by joining the ../data/raw directory with the given file_name. It then sets the expected file extension to .csv. The function then checks if the file_path ends with the expected file extension. If it doesn't, the function prints an error message. If it does, the function checks if the file exists at file_path, and if it does, it removes it and prints a success message. If the file doesn't exist, the function prints a "not found" message. like this:

# %%
def rename(old_filename, new_filename):
    old_file_path = os.path.join("..", "data", old_filename)
    new_file_path = os.path.join("..", "data", new_filename)
    try:
        os.rename(old_file_path, new_file_path)
        print(f"{old_filename} renamed to {new_filename} successfully")
    except FileNotFoundError:
        print(f"{old_filename} not found")
    except FileExistsError:
        print(f"A file with the name {new_filename} already exists")
    except OSError:
        print("Invalid file path or name")

# %% [markdown]
# #### Replace

# %%
def replace(input_str, find_str, replace_str):
    output_str = re.sub(find_str, replace_str, input_str)
    
    if output_str == input_str:
        warnings.warn("Replacement unsuccessful: '{}' not found in input string.".format(find_str))
    
    return output_str

# %%
####  tabler

"""The code defines a function tabler that generates an HTML table with information on the files in a given folder and
adds a section header that contains the directory path 
"""

def tabler(folder_path):
    """
    Generate an HTML table with information on files in a given folder.

    Parameters:
    - folder_path (str): The path to the folder containing the files.

    Returns:
    - str: The HTML code for the table.
    """
    # Get the contents of the folder
    try:
        contents = os.listdir(folder_path)
    except FileNotFoundError:
        return "Directory not found"
    except OSError:
        return "Invalid folder path"

    # Create the section header
    header = f"### {folder_path}\n\n"

    # Create the table header
    table = '<table style="font-size:100%"><thead><tr><th>File Name</th><th>Size</th><th>Modified Time</th></tr></thead><tbody>'

    # Add a row for each file
    for item in contents:
        item_path = os.path.join(folder_path, item)
        if os.path.isfile(item_path):
            # Get the file size and modified time
            size_bytes = os.path.getsize(item_path)
            size_kb = size_bytes / 1024
            size_str = '{:,.2f} KB'.format(size_kb)
            modified_time = datetime.datetime.fromtimestamp(os.path.getmtime(item_path)).strftime('%Y-%m-%d %H:%M')
            # Add a row to the table
            table += '<tr><td>{}</td><td>{}</td><td>{}</td></tr>'.format(item, size_str, modified_time)

    # Close the table
    table += '</tbody></table>'

    return header + table
